# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\train.csv")
df.head()
df.shape
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
# ...

# %%
# Data Preprocessing

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df["LoanAmount"]=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# ...

# %%
#handling categorical missing values

# %%
df["Gender"]=df["Gender"].fillna(df["Gender"].mode()[0])

# %%
#Exploratory Data Analysis

# %%
#categorial data
import seaborn as sns
sns.countplot(df["Gender"])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.displot(df["LoanAmount"])
plt.show()

# %%
sns.countplot(df["Credit_History"])
# Out:
# <Axes: ylabel='count'>

# %%
df['Credit_History'] = df['Credit_History'].astype('string')
plt.show()

# %%
df['TotalIncome']=df['ApplicantIncome']+df['CoapplicantIncome']

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  TotalIncome
# 0            1.0         Urban           Y       5849.0
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#     Credit_History Property_Area Loan_Status  TotalIncome
# 609            1.0         Rural           Y       2900.0
# ...

# %%
df['ApplicantIncomeLog']=np.log(df['ApplicantIncome'])
sns.displot(df['ApplicantIncomeLog'])
plt.show()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  TotalIncome  ApplicantIncomeLog
# 0            1.0         Urban           Y       5849.0            8.674026
# ...

# %%
df['CoapplicantIncomeLog']=np.log(df['CoapplicantIncome'])
sns.displot(df['CoapplicantIncomeLog'])
plt.show()
# Out:
# e:\College\venv\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df['LoanAmountLog']=np.log(df['LoanAmount'])
sns.displot(df['LoanAmountLog'])
plt.show()

# %%
df["TotalIncomeLog"]=np.log(df['TotalIncome'])
sns.displot(df['TotalIncomeLog'])
plt.show()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  TotalIncome  ApplicantIncomeLog  \
# 0            1.0         Urban           Y       5849.0            8.674026
# ...

# %%
df['Loan_Amount_Term_Log']=np.log(df['Loan_Amount_Term'])
sns.displot(df['Loan_Amount_Term_Log'])
plt.show()

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#   Credit_History Property_Area Loan_Status  TotalIncome  ApplicantIncomeLog  \
# 0            1.0         Urban           Y       5849.0            8.674026
# ...

# %%
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','TotalIncome','Loan_Amount_Term','Loan_ID']
df.drop(columns=cols,inplace=True)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed Credit_History  \
# 0   Male      No          0      Graduate            No            1.0
# 1   Male     Yes          1      Graduate            No            1.0
# 2   Male     Yes          0      Graduate           Yes            1.0
# 3   Male     Yes          0  Not Graduate            No            1.0
# 4   Male      No          0      Graduate            No            1.0
#
#   Property_Area Loan_Status  ApplicantIncomeLog  CoapplicantIncomeLog  \
# 0         Urban           Y            8.674026                  -inf
# 1         Rural           N            8.430109              7.318540
# 2         Urban           Y            8.006368                  -inf
# 3         Urban           Y            7.856707              7.765569
# 4         Urban           Y            8.699515                  -inf
#
#    LoanAmountLog  TotalIncomeLog  Loan_Amount_Term_Log
# 0       4.986426        8.674026              5.886104
# ...

# %%
df.Education.value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
d1=pd.get_dummies(df['Gender'],drop_first=True)
d2=pd.get_dummies(df['Married'],drop_first=True)
d3=pd.get_dummies(df['Dependents'],drop_first=True)
d4=pd.get_dummies(df['Education'],drop_first=True)
d5=pd.get_dummies(df['Self_Employed'],drop_first=True)
d6=pd.get_dummies(df['Property_Area'],drop_first=True)

df1=pd.concat([df,d1,d2,d3,d4,d5,d6],axis=1)
df=df1
cols=['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
df.drop(columns=cols,inplace=True)
df.head()
# Out:
#   Credit_History Loan_Status  ApplicantIncomeLog  CoapplicantIncomeLog  \
# 0            1.0           Y            8.674026                  -inf
# 1            1.0           N            8.430109              7.318540
# 2            1.0           Y            8.006368                  -inf
# 3            1.0           Y            7.856707              7.765569
# 4            1.0           Y            8.699515                  -inf
#
#    LoanAmountLog  TotalIncomeLog  Loan_Amount_Term_Log  Male    Yes      1  \
# 0       4.986426        8.674026              5.886104  True  False  False
# 1       4.852030        8.714568              5.886104  True   True   True
# 2       4.189655        8.006368              5.886104  True   True  False
# 3       4.787492        8.505323              5.886104  True   True  False
# 4       4.948760        8.699515              5.886104  True  False  False
#
#        2     3+  Not Graduate    Yes  Semiurban  Urban
# ...

# %%
df.drop(columns=['CoapplicantIncomeLog'],inplace=True)

# %%
df.head()
# Out:
#   Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0            1.0           Y            8.674026       4.986426
# 1            1.0           N            8.430109       4.852030
# 2            1.0           Y            8.006368       4.189655
# 3            1.0           Y            7.856707       4.787492
# 4            1.0           Y            8.699515       4.948760
#
#    TotalIncomeLog  Loan_Amount_Term_Log  Male    Yes      1      2     3+  \
# 0        8.674026              5.886104  True  False  False  False  False
# 1        8.714568              5.886104  True   True   True  False  False
# 2        8.006368              5.886104  True   True  False  False  False
# 3        8.505323              5.886104  True   True  False  False  False
# 4        8.699515              5.886104  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# 1         False  False      False  False
# ...

# %%
###Test Data

# %%
test=pd.read_csv(r"C:\Users\DELL\Downloads\test.csv")
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
test['LoanAmount']=test['LoanAmount'].fillna(test['LoanAmount'].mean())

# %%
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
#Loan_Amount_Term
test['Loan_Amount_Term']=test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mode()[0])

#Credit_History
test['Credit_History']=test['Credit_History'].fillna(test['Credit_History'].mode()[0])

# %%
test.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         367 non-null    float64
#  9   Loan_Amount_Term   367 non-null    float64
#  10  Credit_History     367 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
#filling missing values in categorical columns
test['Gender']=test['Gender'].fillna(test['Gender'].mode()[0])
test['Dependents']=test['Dependents'].fillna(test['Dependents'].mode()[0])
test['Self_Employed']=test['Self_Employed'].fillna(test['Self_Employed'].mode()[0])

# %%
test.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
test['TotalIncome']=test['ApplicantIncome']+test['CoapplicantIncome']

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  TotalIncome
# 0             1.0         Urban         5720
# 1             1.0         Urban         4576
# ...

# %%
#applying log transformation
test['ApplicantIncomeLog']=np.log(test['ApplicantIncome'])
test['CoapplicantIncomeLog']=np.log(test['CoapplicantIncome'])
test['LoanAmountLog']=np.log(test['LoanAmount'])
test['Loan_Amount_Term_Log']=np.log(test['Loan_Amount_Term'])
test['TotalIncomeLog']=np.log(test['TotalIncome'])
# Out:
# e:\College\venv\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# e:\College\venv\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area  TotalIncome  ApplicantIncomeLog  \
# 0             1.0         Urban         5720            8.651724
# ...

# %%
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','TotalIncome','Loan_Amount_Term','Loan_ID','CoapplicantIncomeLog']
test=test.drop(columns=cols,axis=1)

# %%
test.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male     Yes          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          2      Graduate            No             1.0
# 3   Male     Yes          2      Graduate            No             1.0
# 4   Male      No          0  Not Graduate            No             1.0
#
#   Property_Area  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 0         Urban            8.651724       4.700480              5.886104
# 1         Urban            8.031385       4.836282              5.886104
# 2         Urban            8.517193       5.337538              5.886104
# 3         Urban            7.757906       4.605170              5.886104
# 4         Urban            8.094378       4.356709              5.886104
#
#    TotalIncomeLog
# 0        8.651724
# 1        8.428581
# 2        8.824678
# ...

# %%
t1=pd.get_dummies(test,columns=['Gender'],drop_first=True)
t2=pd.get_dummies(test,columns=['Married'],drop_first=True)
t3=pd.get_dummies(test,columns=['Dependents'],drop_first=True)
t4=pd.get_dummies(test,columns=['Education'],drop_first=True)
t5=pd.get_dummies(test,columns=['Self_Employed'],drop_first=True)
t6=pd.get_dummies(test,columns=['Property_Area'],drop_first=True)
test=pd.concat([t1,t2,t3,t4,t5,t6],axis=1)
test.head()
# Out:
#   Married  Dependents     Education Self_Employed Credit_History  \
# 0     Yes           0      Graduate            No            1.0
# 1     Yes           1      Graduate            No            1.0
# 2     Yes           2      Graduate            No            1.0
# 3     Yes           2      Graduate            No            1.0
# 4      No           0  Not Graduate            No            1.0
#
#   Property_Area ApplicantIncomeLog  LoanAmountLog Loan_Amount_Term_Log  \
# 0         Urban           8.651724       4.700480             5.886104
# 1         Urban           8.031385       4.836282             5.886104
# 2         Urban           8.517193       5.337538             5.886104
# 3         Urban           7.757906       4.605170             5.886104
# 4         Urban           8.094378       4.356709             5.886104
#
#    TotalIncomeLog  ...  Dependents     Education Self_Employed Credit_History  \
# ...

# %%
cols=['Gender','Married','Dependents','Education','Self_Employed','Property_Area']
test=test.drop(columns=cols,axis=1)
test.head()
# Out:
#    Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 0             1.0            8.651724       4.700480              5.886104
# 1             1.0            8.031385       4.836282              5.886104
# 2             1.0            8.517193       5.337538              5.886104
# 3             1.0            7.757906       4.605170              5.886104
# 4             1.0            8.094378       4.356709              5.886104
#
#    TotalIncomeLog  Gender_Male  Credit_History  ApplicantIncomeLog  \
# 0        8.651724         True             1.0            8.651724
# 1        8.428581         True             1.0            8.031385
# 2        8.824678         True             1.0            8.517193
# 3        8.494129         True             1.0            7.757906
# 4        8.094378         True             1.0            8.094378
#
#    LoanAmountLog  Loan_Amount_Term_Log  ...  Loan_Amount_Term_Log  \
# ...

# %%
#split dataset

# %%
df.head()
# Out:
#   Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0            1.0           Y            8.674026       4.986426
# 1            1.0           N            8.430109       4.852030
# 2            1.0           Y            8.006368       4.189655
# 3            1.0           Y            7.856707       4.787492
# 4            1.0           Y            8.699515       4.948760
#
#    TotalIncomeLog  Loan_Amount_Term_Log  Male    Yes      1      2     3+  \
# 0        8.674026              5.886104  True  False  False  False  False
# 1        8.714568              5.886104  True   True   True  False  False
# 2        8.006368              5.886104  True   True  False  False  False
# 3        8.505323              5.886104  True   True  False  False  False
# 4        8.699515              5.886104  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# 1         False  False      False  False
# ...

# %%
#specify input and output attributes
x=df.drop(columns=['Loan_Status'],axis=1)
y=df['Loan_Status']

# %%
df.head()
# Out:
#   Credit_History Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0            1.0           Y            8.674026       4.986426
# 1            1.0           N            8.430109       4.852030
# 2            1.0           Y            8.006368       4.189655
# 3            1.0           Y            7.856707       4.787492
# 4            1.0           Y            8.699515       4.948760
#
#    TotalIncomeLog  Loan_Amount_Term_Log  Male    Yes      1      2     3+  \
# 0        8.674026              5.886104  True  False  False  False  False
# 1        8.714568              5.886104  True   True   True  False  False
# 2        8.006368              5.886104  True   True  False  False  False
# 3        8.505323              5.886104  True   True  False  False  False
# 4        8.699515              5.886104  True  False  False  False  False
#
#    Not Graduate    Yes  Semiurban  Urban
# 0         False  False      False   True
# 1         False  False      False  False
# ...

# %%
test.head()
# Out:
#    Credit_History  ApplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  \
# 0             1.0            8.651724       4.700480              5.886104
# 1             1.0            8.031385       4.836282              5.886104
# 2             1.0            8.517193       5.337538              5.886104
# 3             1.0            7.757906       4.605170              5.886104
# 4             1.0            8.094378       4.356709              5.886104
#
#    TotalIncomeLog  Gender_Male  Credit_History  ApplicantIncomeLog  \
# 0        8.651724         True             1.0            8.651724
# 1        8.428581         True             1.0            8.031385
# 2        8.824678         True             1.0            8.517193
# 3        8.494129         True             1.0            7.757906
# 4        8.094378         True             1.0            8.094378
#
#    LoanAmountLog  Loan_Amount_Term_Log  ...  Loan_Amount_Term_Log  \
# ...

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.head()
# Out:
#     Credit_History  ApplicantIncomeLog  LoanAmountLog  TotalIncomeLog  \
# 92             1.0            8.093462       4.394449        8.535622
# 304            1.0            8.294050       4.941642        8.779557
# 68             1.0            8.867850       4.828314        8.867850
# 15             1.0            8.507143       4.828314        8.507143
# 211            0.0            8.140316       4.852030        8.451053
#
#      Loan_Amount_Term_Log  Male    Yes      1      2     3+  Not Graduate  \
# 92               5.886104  True   True  False   True  False          True
# 304              5.886104  True  False  False  False  False         False
# 68               4.094345  True   True  False  False   True          True
# 15               5.886104  True  False  False  False  False         False
# 211              5.886104  True   True  False  False   True         False
#
#        Yes  Semiurban  Urban
# 92   False      False   True
# 304  False      False  False
# ...

# %%
x_test.head()
# Out:
#     Credit_History  ApplicantIncomeLog  LoanAmountLog  TotalIncomeLog  \
# 350            1.0            9.114160       5.429346        9.114160
# 377           <NA>            8.368693       4.867534        8.368693
# 163            1.0            8.334952       5.062595        8.633019
# 609            1.0            7.972466       4.262680        7.972466
# 132            1.0            7.907652       4.248495        7.907652
#
#      Loan_Amount_Term_Log   Male    Yes      1      2     3+  Not Graduate  \
# 350              5.886104   True   True  False  False  False         False
# 377              5.886104   True   True  False  False  False         False
# 163              5.886104   True   True  False   True  False         False
# 609              5.886104  False  False  False  False  False         False
# 132              5.886104   True  False  False  False  False         False
#
#        Yes  Semiurban  Urban
# 350  False       True  False
# 377  False       True  False
# ...

# %%
y_train.head()
# Out:
# 92     Y
# 304    Y
# 68     Y
# 15     Y
# 211    N
# Name: Loan_Status, dtype: object

# %%
y_test.head()
# Out:
# 350    Y
# 377    Y
# 163    Y
# 609    Y
# 132    Y
# Name: Loan_Status, dtype: object

# %%
# Model Training
#Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# Random Forest is an ensemble learning method that combines multiple decision trees to improve classification accuracy.

# %%
print("Accuracy is:", model.score(x_test, y_test)*100)
# Out:
# Accuracy is: 76.62337662337663

# %%
# Descision Tree Classifier

# %%
# Decision Tree Classifier is a supervised learning algorithm used for classification tasks. It works by splitting the data into subsets based on the value of input features, creating a tree-like model of decisions.

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier()
model2.fit(x_train, y_train)
print("Accuracy is:", model2.score(x_test, y_test)*100)
# Out:
# Accuracy is: 72.72727272727273

# %%
#Logistic Regression

# %%
#Logistic Regression predicts the probability of a binary outcome based on one or more predictor variables using the logistic function.

# %%
from sklearn.impute import SimpleImputer

# Create an imputer to replace NaN values with the column mean
imputer = SimpleImputer(strategy='mean')

# Fit on training data and transform both training and test sets
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model3 = LogisticRegression()
model3.fit(x_train, y_train)
print("Accuracy is:", model3.score(x_test, y_test)*100)
# Out:
# Accuracy is: 77.27272727272727

# %%
#model save
import pickle
file=open('model.pkl', 'wb')
pickle.dump(model, file)

# %%
from sklearn.metrics import confusion_matrix
y_pred=model.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
# Out:
# e:\College\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
cm
# Out:
# array([[22, 32],
#        [ 4, 96]])
